# %% [markdown]
# # Tarea 2

# %% [markdown]
# I. Copia el siguiente diccionario en una cédula de Colab. A partir de él, crea un dataframe
# llamado nfo utilizando Pandas.
#
# data_ciudades = {
#
# ′Ciudad′: [′Lima′, ′Arequipa′, ′Trujillo′,′Cusco′, ′Chiclayo′, ′Piura′, ′Iquitos′,′Huancayo′, ′Tacna′, ′Pucallpa′],
# ′Habitantes′: [1047996,100169, 92331,428450, 305717, 484475,441649, 385098,294395, 283734],
# ′Area_km2′: [2672. 28,1545. 77, 1487. 7,116. 5, 279. 89,6217. 26, 368.9, 109. 19, 59.4, 483. 44],
#
# ′Altitud_m′: [154, 2325,34, 3399, 29,29, 106, 3271, 562,156],
#
# ′Densidad_poblacion_por_km2′: [3924,64. 8, 62. 1,3673, 1091. 6, 77.9, 1196, 3528.6, 4966, 587. 2]

# %%
import pandas as pd

# %%
data_ciudades = {
    'Ciudad': ['Lima', 'Arequipa', ' Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Iquitos', 'Huancayo', 'Tacna', 'Pucallpa'],
    'Habitantes': [1047996, 100169, 92331, 428450, 305717, 484475, 441649, 385098, 294395, 283734],
    'Area_km2': [2672.28, 1545.77, 1487.7, 116.5, 279.89, 6217.26, 368.9, 109.19, 59.4, 483.44],
    'Altitud_m': [154, 2325,  34, 3399, 29, 29, 106, 3271, 562, 156],
    'Densidad_poblacion_por_km2': [3924, 64.8, 62.1, 3673, 1091.6, 77.9, 1196, 3528.6, 4966, 587.2]
}
nfo = pd.DataFrame(data_ciudades)
nfo
# Out:
#       Ciudad  Habitantes  Area_km2  Altitud_m  Densidad_poblacion_por_km2
# 0       Lima     1047996   2672.28        154                      3924.0
# 1   Arequipa      100169   1545.77       2325                        64.8
# 2   Trujillo       92331   1487.70         34                        62.1
# 3      Cusco      428450    116.50       3399                      3673.0
# 4   Chiclayo      305717    279.89         29                      1091.6
# 5      Piura      484475   6217.26         29                        77.9
# 6    Iquitos      441649    368.90        106                      1196.0
# 7   Huancayo      385098    109.19       3271                      3528.6
# 8      Tacna      294395     59.40        562                      4966.0
# 9   Pucallpa      283734    483.44        156                       587.2

# %% [markdown]
# II. Realiza el mismo procedimiento con el siguiente diccionario. A partir de él, crea un
# dataframe llamado nombres.
#
# data_ciudades_2 = {
#
# ′Ciudad′: [′Lima′, ′Arequipa′, ′Trujillo′,′Cusco′, ′Chiclayo′, ′Piura′, ′Iquitos′,′Huancayo′, ′Tacna′, ′Pucallpa′],
# ′Gentilicio′: [′Limense′, ′Arequipeño′, ′Trujillano′, ′Cusqueño′, ′Chiclayano′, ′Piurano′, ′Iquiteño′,′Huancaino′, ′Tacneño′, ′Pucallpino′],
# ′Provincia′: [′Lima′, ′Arequipa′, ′Trujillo′,′Cusco′, ′Chiclayo′, ′Piura′, ′Maynas′, ′Huancayo′, ′Tacna′, ′Coronel Portillo′],
# ′Region′: [′Lima′, ′Arequipa′, ′La Libertad′, ′Cusco′, ′Lambayeque′,′Piura′, ′Loreto′, ′Junín′, ′Tacna′, ′Ucayali′]

# %%
data_ciudades2 = {
    'Ciudad': ['Lima','Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Iquitos', 'Huancayo', 'Tacna', 'Pucallpa'],
    'Gentilicio': ['Limense', 'Arequipeño', 'Trujillano', 'Cusqueño', 'Chiclayano', 'Piurano', 'Iquiteño', 'Huancaíno', 'Tacneño', 'Pucallpino'],
    'Provincia': ['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Maynas', 'Huancayo', 'Tacna', 'Coronel Portillo'],
    'Region': ['Lima', 'Arequipa', 'La Libertad', 'Cusco', 'Lambayeque', 'Piura', 'Loreto', 'Junín', 'Tacna', 'Ucayali']
}

nombres = pd.DataFrame(data_ciudades2)
nombres
# Out:
#      Ciudad  Gentilicio         Provincia       Region
# 0      Lima     Limense              Lima         Lima
# 1  Arequipa  Arequipeño          Arequipa     Arequipa
# 2  Trujillo  Trujillano          Trujillo  La Libertad
# 3     Cusco    Cusqueño             Cusco        Cusco
# 4  Chiclayo  Chiclayano          Chiclayo   Lambayeque
# 5     Piura     Piurano             Piura        Piura
# 6   Iquitos    Iquiteño            Maynas       Loreto
# 7  Huancayo   Huancaíno          Huancayo        Junín
# 8     Tacna     Tacneño             Tacna        Tacna
# 9  Pucallpa  Pucallpino  Coronel Portillo      Ucayali

# %% [markdown]
# III. Con ambos dataframes, realiza un inner join. Guarda el resultado en un nuevo dataframe
# llamado cuadro_1

# %%
cuadro_1 = pd.merge(nfo, nombres, on='Ciudad', how='inner')
cuadro_1
# Out:
#      Ciudad  Habitantes  Area_km2  Altitud_m  Densidad_poblacion_por_km2  \
# 0      Lima     1047996   2672.28        154                      3924.0
# 1  Arequipa      100169   1545.77       2325                        64.8
# 2     Cusco      428450    116.50       3399                      3673.0
# 3  Chiclayo      305717    279.89         29                      1091.6
# 4     Piura      484475   6217.26         29                        77.9
# 5   Iquitos      441649    368.90        106                      1196.0
# 6  Huancayo      385098    109.19       3271                      3528.6
# 7     Tacna      294395     59.40        562                      4966.0
# 8  Pucallpa      283734    483.44        156                       587.2
#
#    Gentilicio         Provincia      Region
# 0     Limense              Lima        Lima
# 1  Arequipeño          Arequipa    Arequipa
# 2    Cusqueño             Cusco       Cusco
# 3  Chiclayano          Chiclayo  Lambayeque
# 4     Piurano             Piura       Piura
# 5    Iquiteño            Maynas      Loreto
# 6   Huancaíno          Huancayo       Junín
# 7     Tacneño             Tacna       Tacna
# 8  Pucallpino  Coronel Portillo     Ucayali

# %% [markdown]
# IV. Resume las estadísticas descriptivas del dataframe y responde ¿Cuál es la mínima
# densidad poblacional? ¿A cuál ciudad corresponde? ¿Y la máxima?

# %%
cuadro_1.describe().T
# Out:
#                             count           mean            std       min  \
# Habitantes                    9.0  419075.888889  262198.412120  100169.0
# Area_km2                      9.0    1316.958889    2032.625878      59.4
# Altitud_m                     9.0    1114.555556    1451.506727      29.0
# Densidad_poblacion_por_km2    9.0    2123.233333    1884.306196      64.8
#
#                                  25%       50%        75%         max
# Habitantes                  294395.0  385098.0  441649.00  1047996.00
# Area_km2                       116.5     368.9    1545.77     6217.26
# Altitud_m                      106.0     156.0    2325.00     3399.00
# Densidad_poblacion_por_km2     587.2    1196.0    3673.00     4966.00

# %%
# Encontrar la mínima y máxima densidad poblacional
min_densidad = cuadro_1['Densidad_poblacion_por_km2'].min()
max_densidad = cuadro_1['Densidad_poblacion_por_km2'].max()

# Encontrar las ciudades correspondientes
ciudad_min_densidad = cuadro_1.loc[cuadro_1['Densidad_poblacion_por_km2'] == min_densidad, 'Ciudad'].values[0]
ciudad_max_densidad = cuadro_1.loc[cuadro_1['Densidad_poblacion_por_km2'] == max_densidad, 'Ciudad'].values[0]

print(f'La mínima densidad poblacional es {min_densidad} por km2 y se encuentra en {ciudad_min_densidad}.')
print(f'\nLa máxima densidad poblacional es {max_densidad} por km2 y se encuentra en {ciudad_max_densidad}.')
# Out:
# La mínima densidad poblacional es 64.8 por km2 y se encuentra en Arequipa.
#
# La máxima densidad poblacional es 4966.0 por km2 y se encuentra en Tacna.

# %% [markdown]
# V. Realizar un gráfico de barras donde se vea la cantidad de habitantes en cada ciudad

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(cuadro_1['Ciudad'], cuadro_1['Habitantes'])
plt.xlabel('Ciudad')
plt.ylabel('Cantidad de Habitantes')
plt.title('Cantidad de Habitantes por Ciudad')
plt.xticks(rotation=45)  # Rota etiquetas
plt.show()

# %% [markdown]
# VI. Realizar un gráfico de dispersión entre la altura y el número de habitantes en las
# ciudades del dataframe.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(cuadro_1['Altitud_m'], cuadro_1['Habitantes'])
plt.xlabel('Altura (m)')
plt.ylabel('Número de Habitantes')
plt.title('Relación entre Altura y Número de Habitantes del Perú')
plt.grid(True)  # cuadrícula
plt.show()
